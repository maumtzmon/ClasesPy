# %%
from functions_py import *
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy.ma as ma

path='/home/oem/datosFits/MicrochipTest_Marzo/datos/14JUN23/proc_skp_m-009_microchip_T_170__Vv82_NSAMP_1_NROW_700_NCOL_700_EXPOSURE_900_NBINROW_1_NBINCOL_1_img_9.fits'
hdu_list = fits.open(path)
print(hdu_list.info())
print('----------------')
# hdu_list[0].header
plt.figure(figsize=(20,10))

#active=np.s_[:640,9:537]
active=np.s_[:,:]
all=np.s_[:,:]

data2plot=hdu_list[0].data-np.median(hdu_list[0].data)
plt.subplot(2,2,1)
plt.imshow(data2plot[active],vmin=-800,vmax=800, origin='lower')
#plt.imshow(np.flip(data2plot,1),vmin=-800,vmax=800, origin='lower')
plt.title('CHID '+str(1))
plt.ylabel('Y_pix')
plt.xlabel('X_pix')


data2plot=hdu_list[1].data-np.median(hdu_list[0].data)
plt.subplot(2,2,3)
plt.imshow(data2plot[active],vmin=-800,vmax=800, origin='lower')
#plt.imshow(np.flip(data2plot,1),vmin=-800,vmax=800, origin='lower')
plt.title('CHID '+str(2))
plt.ylabel('Y_pix')
plt.xlabel('X_pix')



data2plot=hdu_list[2].data-np.median(hdu_list[0].data)
plt.subplot(2,2,4)
plt.imshow(data2plot[active],vmin=-800,vmax=800, origin='lower')
#plt.imshow(np.flip(data2plot,1),vmin=-800,vmax=800, origin='lower')
plt.title('CHID '+str(3))
plt.ylabel('Y_pix')
plt.xlabel('X_pix')



data2plot=hdu_list[3].data-np.median(hdu_list[0].data)
plt.subplot(2,2,2)
plt.imshow(data2plot[active],vmin=-800,vmax=800, origin='lower')
#plt.imshow(np.flip(data2plot,1),vmin=-800,vmax=800, origin='lower')
plt.title('CHID '+str(4))
plt.ylabel('Y_pix')
plt.xlabel('X_pix')

plt.show()
# Out:
# Filename: /home/oem/datosFits/MicrochipTest_Marzo/datos/14JUN23/proc_skp_m-009_microchip_T_170__Vv82_NSAMP_1_NROW_700_NCOL_700_EXPOSURE_900_NBINROW_1_NBINCOL_1_img_9.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     165   (700, 700)   float32
#   1                1 ImageHDU       164   (700, 700)   float32
#   2                1 ImageHDU       164   (700, 700)   float32
#   3                1 ImageHDU       164   (700, 700)   float32
# None
# ----------------

# %%
Ext_1=np.flip(data2plot[active], 0)
Ext_2=data2plot[active]
Ext_3=np.flip(data2plot[active], 1)
Ext_4=np.flip(np.flip(data2plot[active], 1),0)

# %%
active=np.s_[:640,9:537]
plt.figure(figsize=(20,10))

data2plot=hdu_list[0].data-np.median(hdu_list[0].data)
Ext_1=np.flip(data2plot[active], 0)
plt.subplot(2,2,1)
plt.imshow(Ext_1,vmin=-800,vmax=800, origin='lower')
#plt.imshow(np.flip(data2plot,1),vmin=-800,vmax=800, origin='lower')
plt.title('CHID '+str(1))
plt.ylabel('Y_pix')
plt.xlabel('X_pix')

data2plot=hdu_list[1].data-np.median(hdu_list[0].data)
Ext_2=data2plot[active]
plt.subplot(2,2,3)
plt.imshow(Ext_2,vmin=-800,vmax=800, origin='lower')
#plt.imshow(np.flip(data2plot,1),vmin=-800,vmax=800, origin='lower')
plt.title('CHID '+str(2))
plt.ylabel('Y_pix')
plt.xlabel('X_pix')

data2plot=hdu_list[2].data-np.median(hdu_list[0].data)
Ext_3=np.flip(data2plot[active], 1)
plt.subplot(2,2,4)
plt.imshow(Ext_3,vmin=-800,vmax=800, origin='lower')
#plt.imshow(np.flip(data2plot,1),vmin=-800,vmax=800, origin='lower')
plt.title('CHID '+str(3))
plt.ylabel('Y_pix')
plt.xlabel('X_pix')


data2plot=hdu_list[3].data-np.median(hdu_list[0].data)
Ext_4=np.flip(np.flip(data2plot[active], 1),0)
plt.subplot(2,2,2)
plt.imshow(Ext_4,vmin=-800,vmax=800, origin='lower')
#plt.imshow(np.flip(data2plot,1),vmin=-800,vmax=800, origin='lower')
plt.title('CHID '+str(4))
plt.ylabel('Y_pix')
plt.xlabel('X_pix')
# Out:
# Text(0.5, 0, 'X_pix')

# %%
plt.figure(figsize=(20,10))
active=np.s_[:640,9:537]
#active=np.s_[:640,:]

data2plot=hdu_list[0].data-np.median(hdu_list[0].data)
#Ext_1=np.flip(data2plot[active], 0)
Ext_1=np.flip(np.flip(data2plot[active], 0), 1)
#Ext_1=data2plot[active]

data2plot=hdu_list[3].data-np.median(hdu_list[0].data)
Ext_2=data2plot[active]
#Ext_2=np.flip(data2plot[active], 0)
#Ext_2=np.flip(np.flip(data2plot[active], 0), 1)

leftHalf=np.concatenate((Ext_1,Ext_2),1)

#plt.subplot(2,2,2)
plt.imshow(leftHalf,vmin=-800,vmax=800, origin='lower')

# %%
OScan=np.s_[:,540:]
active_all=np.s_[:,:]
active=np.s_[:640,9:537]

data2plot=hdu_list[0].data-np.median(hdu_list[0].data)
#Ext_1=np.flip(data2plot[active], 0)
Ext_1=data2plot[active_all]

data2plot=hdu_list[1].data-np.median(hdu_list[0].data)
#Ext_1=np.flip(data2plot[active], 0)
Ext_1=data2plot[active_all]

hist,bins=np.histogram(Ext_1[OScan].flatten(), bins=10000)
offset = bins[np.argmax(hist)]
Ext_1=Ext_1-offset

hist,bins=np.histogram(Ext_2[OScan].flatten(), bins=10000)
offset = bins[np.argmax(hist)]
Ext_2=Ext_2-offset

# %%
plt.figure(figsize=(20,10))
active=np.s_[:640,9:537]


leftHalf=np.concatenate((Ext_1,Ext_2),1)

#plt.subplot(2,2,2)
plt.imshow(leftHalf,vmin=-800,vmax=800, origin='lower')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/oem/Software/cursoInstrumentacion_2022/ClasesPy/70 - ICN_LabDet/plot_fitsImage.ipynb Celda 6 in 5
#       <a href='vscode-notebook-cell:/home/oem/Software/cursoInstrumentacion_2022/ClasesPy/70%20-%20ICN_LabDet/plot_fitsImage.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(20,10))
#       <a href='vscode-notebook-cell:/home/oem/Software/cursoInstrumentacion_2022/ClasesPy/70%20-%20ICN_LabDet/plot_fitsImage.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> active=np.s_[:640,9:537]
# ----> <a href='vscode-notebook-cell:/home/oem/Software/cursoInstrumentacion_2022/ClasesPy/70%20-%20ICN_LabDet/plot_fitsImage.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> leftHalf=np.concatenate((Ext_1,Ext_2),1)
#       <a href='vscode-notebook-cell:/home/oem/Software/cursoInstrumentacion_2022/ClasesPy/70%20-%20ICN_LabDet/plot_fitsImage.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a> #plt.subplot(2,2,2)
#       <a href='vscode-notebook-cell:/home/oem/Software/cursoInstrumentacion_2022/ClasesPy/70%20-%20ICN_LabDet/plot_fitsImage.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a> plt.imshow(leftHalf,vmin=-800,vmax=800, origin='lower')
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 700 and the array at index 1 has size 640
