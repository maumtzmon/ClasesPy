# %%
from checknoise import plotCheckNoise as PltNoise

# %%
PltNoise(files="/home/maumtz/datosFits/testMITLL/16NOV22/proc_skp_module26_MITLL01_externalVr_Vtest_T170_testLeakage__NSAMP324_NROW50_NCOL700_EXPOSURE0_NBINROW1_NBINCOL1_img37.fits")
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# /home/maumtz/Software/ClasesPy/29 - matplotlib/fwd/checkNoise.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/maumtz/Software/ClasesPy/29%20-%20matplotlib/fwd/checkNoise.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> PltNoise(files="/home/maumtz/datosFits/testMITLL/16NOV22/proc_skp_module26_MITLL01_externalVr_Vtest_T170_testLeakage__NSAMP324_NROW50_NCOL700_EXPOSURE0_NBINROW1_NBINCOL1_img37.fits")
#
# File ~/Software/ClasesPy/29 - matplotlib/fwd/checknoise.py:49, in plotCheckNoise(files)
#      38 #	fig_all.tight_layout()
#      39
#      40 	# Open datafile and write header
#      41 #	datafile=open(dirname+"/noisevspsamp.txt","a+")
#      42 #	datafile.write("#PSAMP\tNoise_ext1\tNoise_ext2\tNoise_ext3\tNoise_ext4\n")
#      44 	for image in files:
# ...
