# %%
import pandas as pd
dataframe=pd.read_csv('/home/oem/datosFits/MicrochipTest_Marzo/datos/23MAY23/skp_m-009_microchip_T_170__Vv_NSAMP_1_NROW_1300_NCOL_650_EXPOSURE_0_NBINROW_1_NBINCOL_1_img_105.csv')

# %%
dataframe.columns=['col_0','col_1','col_2','col_3']

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(dataframe)

# %%
dataframe
# Out:
#        col_0  col_1  col_2  col_3
# 0         13      4      0  11723
# 1         14      4      0  11681
# 2         15      4      0  11638
# 3          0      4      0  11600
# 4          1      4      0  11565
# ...      ...    ...    ...    ...
# 65530      7      4      2 -36468
# 65531      8      4      2 -35925
# 65532      9      4      2 -35410
# 65533     10      4      2 -34910
# 65534     11      4      2 -34437
#
# [65535 rows x 4 columns]

# %%
dataframe['col_0']
# Out:
# 0        13
# 1        14
# 2        15
# 3         0
# 4         1
#          ..
# 65530     7
# 65531     8
# 65532     9
# 65533    10
# 65534    11
# Name: col_0, Length: 65535, dtype: int64

# %%
plt.plot(dataframe['col_0'][0:50])

# %%
data_0=dataframe['col_0']
data_1=dataframe['col_1']
data_2=dataframe['col_2']
data_3=dataframe['col_3']

# %%
fig, ax1=plt.subplots()
color = 'tab:red'
t_ini=0
t_end=50
ax1.set_xlabel('time (s)')
ax1.set_ylabel('exp', color=color)
ax1.plot(data_0[t_ini:t_end], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('sin', color=color)  # we already handled the x-label with ax1
ax2.plot(data_1[t_ini:t_end], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
